# %% [markdown]
# # Application of Fuzzy logic and Genetic Algorithm in Stock Trading
#
# This notebook explores the application of genetic algorithms in optimizing the fuzzy rules as applied in technical analysis of stocks.

# %%
# import libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
from Genome import Genome
from Population import Population
from Fitness import evaluate_fitness, test_fitness
from Base_genome import base_genome
from Seed_genome import seed_genome
from helper_module import split_train_test_sets, split_train_set
from Evolution import Evolution

# %%
# read and print sample historical stock price data
series = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/GLO.csv', header = 0, index_col = 'Date')
print(series)

# plot historical stock price data
fig, ax = plt.subplots()    
ax.set_title('GLO closing prices')
ax.set_xlabel('Date')
ax.set_ylabel('Price (Pesos)')
ax.plot(series['Close'].tail(60))
ax.set_xticks(ax.get_xticks()[::13])
plt.show()
# Out:
#                 Close       Open       High        Low   Volume
# Date
# 1986-01-02   172.6575   172.6575   172.6575   172.6575    600.0
# 1986-01-03   172.6575   172.6575   172.6575   172.6575   1900.0
# 1986-01-06   175.4879   175.4879   175.4879   175.4879   2800.0
# 1986-01-07   181.1488   175.4879   181.1488   175.4879   3200.0
# 1986-01-09   181.1488   181.1488   181.1488   181.1488   2600.0
# ...               ...        ...        ...        ...      ...
# 2023-09-12  1781.0000  1786.0000  1809.0000  1781.0000  12985.0
# 2023-09-13  1787.0000  1799.0000  1799.0000  1781.0000  16850.0
# 2023-09-14  1795.0000  1795.0000  1795.0000  1782.0000  12070.0
# 2023-09-15  1752.0000  1795.0000  1810.0000  1752.0000  29105.0
# 2023-09-18  1752.0000  1789.0000  1789.0000  1752.0000  27225.0
#
# [8861 rows x 5 columns]

# %%
# split data into train and test sets
train, test = split_train_test_sets(series)

# plot the train and test sets
fig, ax = plt.subplots()    
ax.set_title('GLO closing prices')
ax.set_xlabel('Date')
ax.set_ylabel('Price (Pesos)')
ax.plot(train['Close'], 'g')
ax.plot(test['Close'], 'r')
ax.set_xticks(ax.get_xticks()[::2000])
plt.show()

# %%
# split the train set into multiple batches
train_set = split_train_set(train)

# plot a sample of the train set
fig, ax = plt.subplots()    
ax.set_title('GLO closing prices')
ax.set_xlabel('Date')
ax.set_ylabel('Price (Pesos)')
ax.plot(train_set[1]['Close'], 'g')
ax.set_xticks(ax.get_xticks()[::100])
plt.show()

# %%
if __name__ == "__main__":
    NUM_SEED_GENOMES = 25
    NUM_BASE_GENOMES = 75
    SEED_GENOME = Genome(seed_genome())
    BASE_GENOME = Genome(base_genome())  
    population = Population()
    population.seed_population(seed_genome = SEED_GENOME, num_seeds = NUM_SEED_GENOMES)
    population.add_and_initialize_to_population(base_genome = BASE_GENOME, num_genomes = NUM_BASE_GENOMES)  
    evolution = Evolution(population = population)
    evolution.define_fitness_func(fitness_func = evaluate_fitness)
    evolution.define_train_set(train_set = train_set)
    new_population = evolution.run(num_generations=50)
# Out:
# Generation 0
# fitness of generation 0:	1.268799345507257
# Generation 1
# fitness of generation 1:	7.662343414992456
# Generation 2
# fitness of generation 2:	17.706321105559798
# Generation 3
# fitness of generation 3:	22.604246958828597
# Generation 4
# fitness of generation 4:	2.746286300256694
# Generation 5
# fitness of generation 5:	3.4093307085687865
# Generation 6
# fitness of generation 6:	4.847753678105525
# Generation 7
# fitness of generation 7:	5.405509566385778
# Generation 8
# fitness of generation 8:	6.8445201401489175
# Generation 9
# fitness of generation 9:	4.7661984001986015
# Generation 10
# fitness of generation 10:	9.294584714265778
# Generation 11
# fitness of generation 11:	6.51759380334942
# Generation 12
# fitness of generation 12:	3.2081036581323135
# Generation 13
# fitness of generation 13:	6.858026421973373
# Generation 14
# fitness of generation 14:	101.88031546926611
# Generation 15
# fitness of generation 15:	5.776016620889905
# Generation 16
# fitness of generation 16:	4.428441984283418
# Generation 17
# fitness of generation 17:	48.166579057023725
# Generation 18
# fitness of generation 18:	105.61130062548342
# Generation 19
# fitness of generation 19:	7.185280314729824
# Generation 20
# fitness of generation 20:	7.579761896013203
# Generation 21
# fitness of generation 21:	8.284430188606143
# Generation 22
# fitness of generation 22:	5.846824762536427
# Generation 23
# fitness of generation 23:	7.455415585476586
# Generation 24
# fitness of generation 24:	5.7083472424683075
# Generation 25
# fitness of generation 25:	7.371136483886314
# Generation 26
# fitness of generation 26:	19.18928043288032
# Generation 27
# fitness of generation 27:	5.652502959786808
# Generation 28
# fitness of generation 28:	5.029050849730255
# Generation 29
# fitness of generation 29:	7.32901644460605
# Generation 30
# fitness of generation 30:	8.211498578361063
# Generation 31
# fitness of generation 31:	8.068775513700617
# Generation 32
# fitness of generation 32:	4.728575254172888
# Generation 33
# fitness of generation 33:	25.407963190417178
# Generation 34
# fitness of generation 34:	3.4863323732229077
# Generation 35
# fitness of generation 35:	357.27317493729856
# Generation 36
# fitness of generation 36:	6.125361913947896
# Generation 37
# fitness of generation 37:	4.310487044201623
# Generation 38
# fitness of generation 38:	3.364328155979544
# Generation 39
# fitness of generation 39:	2.281735277921
# Generation 40
# fitness of generation 40:	3.127552701865039
# Generation 41
# fitness of generation 41:	7.726587370058496
# Generation 42
# fitness of generation 42:	10.063191397334753
# Generation 43
# fitness of generation 43:	6.61525335333344
# Generation 44
# fitness of generation 44:	3.1385174395368582
# Generation 45
# fitness of generation 45:	2.4118456757780713
# Generation 46
# fitness of generation 46:	8.049336966549191
# Generation 47
# fitness of generation 47:	5.44693305960841
# Generation 48
# fitness of generation 48:	3.006707051004323
# Generation 49
# fitness of generation 49:	3.349872867774752

# %%
series_JFC = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/JFC.csv', header = 0, index_col = 'Date')
series_CEB = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/CEB.csv', header = 0, index_col = 'Date')
series_GTCAP = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/GTCAP.csv', header = 0, index_col = 'Date')
series_AEV = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/AEV.csv', header = 0, index_col = 'Date')
series_BPI = pd.read_csv('../../Data/PH-historical-stock-price-data-csv/BPI.csv', header = 0, index_col = 'Date')

# %%
# print(population.population[25])
print(evolution.population.population[0])
fitness, num_trades = test_fitness(genome = new_population .population[99], series = test)
print(num_trades)
# Out:
# GENE_ID: 2520
# Gene name: RSI_window
# Value: 272
#
# Gene name: RSI_p1
# Value: 0.8672512307855533
#
# Gene name: RSI_p2
# Value: -0.29592026000556504
#
# Gene name: RSI_p3
# Value: 0.5684377286494632
#
# Gene name: RSI_p4
# Value: 0.2593177615486474
#
# Gene name: RSI_low_membership
# Value: [51.34364468396732, 78.84269109442587]
#
# Gene name: RSI_middle_membership
# Value: [5.705637321298725, 8.921714980463793, 62.30533934822536]
#
# Gene name: RSI_high_membership
# Value: [73.16469553629946, 89.79247612241305]
#
# Gene name: entry_condition
# Value: [6.851563272961426, 55.93293586762963]
#
# Gene name: stop_loss
# Value: 0.0863334017021653
#
# Gene name: z_rolling_window
# Value: 201
# 1
